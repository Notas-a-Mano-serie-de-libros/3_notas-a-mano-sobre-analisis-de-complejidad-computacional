# %% [markdown]
# # Laboratorio de ejercicios propuestos: algoritmos de ordenamiento · laboratorio ejecutable
#
# Este notebook conserva el código, los controles y la animación. La explicación, las ecuaciones y la interpretación de resultados se encuentran en el complemento digital:
#
# <div style="margin:1.25rem 0 1.5rem;padding:18px 20px;border:1px solid #bdb9b2;border-left:4px solid #8b4b32;background:#fbfaf7;color:#242321;font-family:Arial,Helvetica,sans-serif;">
#   <div style="margin-bottom:6px;color:#8b4b32;font-size:11px;font-weight:700;letter-spacing:.08em;text-transform:uppercase;">Complemento digital</div>
#   <div style="margin-bottom:14px;font-size:15px;line-height:1.55;">Consulta la explicación, las ecuaciones y la interpretación de resultados en el sitio de la obra.</div>
#   <a class="notebook-pages-button" href="https://notas-a-mano-serie-de-libros.github.io/3_notas-a-mano-sobre-analisis-de-complejidad-computacional/capitulos/capitulo-8/ejercicios-propuestos/" target="_blank" rel="noopener noreferrer" aria-label="Leer la explicación completa en GitHub Pages; abre una pestaña nueva">
#     <img src="https://img.shields.io/badge/LEER_LA_EXPLICACI%C3%93N_COMPLETA_EN_GITHUB_PAGES-33312e?style=for-the-badge&logo=github&logoColor=white" alt="Leer la explicación completa en GitHub Pages" width="430" />
#   </a>
# </div>
#
# Ejecuta las celdas en orden y utiliza los controles de la simulación. Al finalizar, vuelve a Pages para contrastar los resultados con el análisis teórico.

# %%
#@title Ejecutar laboratorio de ordenamientos { display-mode: "form" }
from pathlib import Path
import importlib, sys, tempfile, urllib.request

_root = next((base for base in (Path.cwd(), *Path.cwd().parents) if (base / "common" / "exercise_laboratory.py").exists()), None)
if _root is None:
    _root = Path(tempfile.gettempdir()) / "notas_mano_exercises"
    (_root / "common").mkdir(parents=True, exist_ok=True)
    (_root / "capitulo8" / "runtime").mkdir(parents=True, exist_ok=True)
    (_root / "capitulo2" / "runtime").mkdir(parents=True, exist_ok=True)
    _base = "https://raw.githubusercontent.com/Notas-a-Mano-serie-de-libros/3_notas-a-mano-sobre-analisis-de-complejidad-computacional/main/"
    for _relative in ("common/__init__.py", "common/experimental_simulation.py", "common/widget_controls.py", "common/simulation_views.py", "common/exercise_laboratory.py", "capitulo2/runtime/experimental_animation.py", "capitulo8/runtime/exercises_lab.py"):
        (_root / _relative).write_bytes(urllib.request.urlopen(_base + _relative).read())
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))
for _module in ("common.exercise_laboratory", "capitulo8.runtime.exercises_lab"):
    sys.modules.pop(_module, None)
importlib.invalidate_caches()
from capitulo8.runtime.exercises_lab import run_app
run_app()
