# %%
import time
import tracemalloc
from scipy.optimize import curve_fit
import numpy as np

from util import graficar_complejidad, modelo_constante, modelo_cuadratico
import matplotlib.pyplot as plt

plt.style.use('default')
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['savefig.facecolor'] = 'white'
plt.rcParams['savefig.edgecolor'] = 'white'

plt.rcParams['figure.dpi'] = 500
plt.rcParams['savefig.dpi'] = 500
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)

# %%
def medir_tiempo_matrices(func, sizes, n_iter):
    tiempos = np.zeros(len(sizes))

    for i, n in enumerate(sizes):
        acumulado = 0.0
        for _ in range(n_iter):
            matriz = np.random.randint(0, 1000, size=(n, n))
            inicio = time.perf_counter()
            func(matriz)
            acumulado += time.perf_counter() - inicio
        tiempos[i] = acumulado / n_iter

    return tiempos

def medir_memoria_matrices(func, sizes, n_iter):
    espacios = np.zeros(len(sizes), dtype=int)

    for i, n in enumerate(sizes):
        acumulado = 0
        for _ in range(n_iter):
            matriz = np.random.randint(0, 1000, size=(n, n))
            tracemalloc.start()
            func(matriz)
            _, peak = tracemalloc.get_traced_memory()
            tracemalloc.stop()
            acumulado += peak
        espacios[i] = acumulado / n_iter

    return espacios

def imprimir_matriz(matriz):
    for fila in matriz:
        for x in fila:
            _ = x

# %%
n_ejecuciones = 250
sizes = np.arange(1, 250, 20)
x = sizes

# %%
tiempos = medir_tiempo_matrices(imprimir_matriz, sizes, n_ejecuciones)
params_tiempo = curve_fit(modelo_cuadratico, sizes**2, tiempos)[0]
tiempos_ajustados = modelo_cuadratico(sizes**2, *params_tiempo)

graficar_complejidad(
    x=sizes,
    y_experimental=tiempos,
    y_teorico=tiempos_ajustados,
    nombre_archivo='ejemplo_imprimir_matriz_tiempo.png',
    ylabel='Tiempo de ejecución [s]',
    funcion='T(n)',
    xlabel='Cantidad de datos de entrada ($m \\cdot n$)'
)

# %%
espacio = medir_memoria_matrices(imprimir_matriz, sizes, n_ejecuciones)
params_espacio = curve_fit(modelo_constante, sizes, espacio)[0]
espacio_ajustado = modelo_constante(sizes, *params_espacio)

graficar_complejidad(
    x=sizes,
    y_experimental=espacio,
    y_teorico=espacio_ajustado,
    nombre_archivo='ejemplo_imprimir_matriz_espacio.png',
    ylabel='Consumo de memoria [bytes]',
    funcion='S(n)',
    xlabel='Cantidad de datos de entrada ($m \\cdot n$)'
)
